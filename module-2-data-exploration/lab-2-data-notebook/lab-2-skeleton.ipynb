# %% [markdown]
# # ASM 532 — Lab 2: Data Notebook
#
# **Name:**
# **Dataset:**
# **Date:**

# %% [markdown]
# ## How to use this template
#
# - This is a skeleton, not a worksheet. Add cells, delete cells, rename sections.
# - **Every step names an outcome, not a method.** Functions listed under *Worth looking at* are suggestions — use them, ignore them, find better ones.
# - **Every code cell starts with your plan, written as comments.** What you intend to do, in order, in plain English — then the code under it. This is the "function designs" step from the course AI policy, and it is what makes the notebook yours.
# - **Markdown is graded work, not decoration.** Every finding gets a sentence saying what you found and what you did about it.
# - Work on **your own dataset**. No dataset of your own? Use `aglandvalues-clean.csv` in this folder — US agricultural land values by state, 1997-2023 — and bring a *problem* to it: something you would want to know from land values.
# - **No AI-generated code.** Hand-crafting the code is the point.
# - Commit as you go. Four commits minimum, more is better.
#
# Check Brightspace for the deadline. Steps 10-12 build on Lecture 2.3, so leave them until after it.

# %% [markdown]
# ## Setup
#
# - Import what you need, when you need it — or all at the top, if you prefer.
# - *Worth looking at:* `pandas`, `numpy`, `matplotlib.pyplot`, `requests`.

# %%
# plan:

# imports

# %% [markdown]
# ---
# # Step 7 — Understand and plan
#
# *The revised version of your Lecture 2.2 worksheet. Markdown only, no code.*
#
# - What is the problem, and who has it?
# - Who are the actors, and what are their goals?
# - **What is your question?** One sentence.
# - What would count as an answer?
# - What changed since the handout? Contact with a real dataset always changes something — say what.

# %% [markdown]
# *Your plan here.*

# %% [markdown]
# ---
# # Step 8 — Acquire
#
# - Get your data into this folder and commit it.
# - Load it into a dataframe.
# - Record where it came from — **this is the part people skip and regret.**
#
# **In markdown, record:**
#
# - Source name and URL
# - Date retrieved
# - Terms of use / licence
# - What you actually got: format, file size, how many rows and columns, anything surprising about the download
#
# **Then judge whether it fits.**
#
# - Name the **three data quality dimensions** from Lecture 2.2 that matter most for your question.
# - Say how your dataset does on each.
# - **At least one should be a dimension it does badly on.** Every dataset fails something; saying which is the skill.
#
# *Worth looking at:* `pd.read_csv()`, `pd.read_excel()`, `pd.read_json()`. If your file will not load, the problem is usually the delimiter, the encoding, or rows of preamble above the header.

# %%
# plan:

# load your data

# %% [markdown]
# *Provenance: where this data came from, and what arrived.*
#
# *Fitness: the three dimensions that matter, how it does on each, and the one it fails.*

# %% [markdown]
# ---
# # Step 9 — Process
#
# *Five questions. Answer each in code, then say what you found in markdown.*
#
# > **Using `aglandvalues-clean.csv`?** It has already been cleaned — the name says so. Your job here is to **verify that, and show how you know**. Run the same five questions and report what you checked and what came back clean. A dataset someone hands you as "clean" still has to be inspected before you trust it, and that inspection is the same work.
#
# ### 1. How big is it, and how big should it be?
#
# - *Worth looking at:* `.shape`, `.info()`, `.head()`, `.tail()`

# %%
# plan:

# %% [markdown]
# ### 2. What is in each column, and is it the type it should be?
#
# - Numbers stored as text are the classic trap — they sort wrong and will not plot.
# - *Worth looking at:* `.dtypes`, `.describe()`, `.value_counts()`, `type()`

# %%
# plan:

# %% [markdown]
# ### 3. What is missing, and how is "missing" spelled in your data?
#
# - `NaN` is only one spelling. Others in the wild: `(NA)`, `(D)`, `(S)`, `-999`, `N/A`, an empty string, a space.
# - *Worth looking at:* `.isna().sum()`, `.value_counts()`, `.str.contains()`, `.unique()`

# %%
# plan:

# %% [markdown]
# ### 4. Is anything duplicated, or in the wrong order?
#
# - *Worth looking at:* `.duplicated()`, `.sort_values()`, `.reset_index()`

# %%
# plan:

# %% [markdown]
# ### 5. Clean it — and keep the raw file.
#
# - Drop, fix, or convert what needs it. Check the shape again afterwards: did you lose rows you meant to keep?
# - Save the cleaned version under a **new filename**. Never overwrite the raw download.
# - *Worth looking at:* `.dropna()`, `.drop()`, `.astype()`, `.str.strip()`, `.str.replace()`, `.to_csv()`

# %%
# plan:

# %% [markdown]
# *What you changed, and why. One line per decision — this is the part a collaborator (or you, in six months) needs.*

# %% [markdown]
# ---
# # Step 10 — Analyze
#
# ### First: plot it badly
#
# - Plot the whole thing, no styling, no subsetting. It will be a mess.
# - **Then say what is wrong with it.** That sentence is the point of this step.
# - *Worth looking at:* `.plot()`, `plt.plot()`

# %%
# plan:

# %% [markdown]
# *What is wrong with that plot?*

# %% [markdown]
# ### Then: two or three visualizations that answer your question
#
# Choose them for *your* question, using the chooser slides from Lecture 2.4 (what data type? what structure? what needs highlighting?). Between them, they must include:
#
# - **one comparison or grouping** — across categories, regions, or time
# - **one that brings in a second variable**, with a sentence on what the pairing shows
#
# Every plot needs a title, axis labels, and a legend where there is more than one series. Save each one as a file and commit it.
#
# *Worth looking at:* `.groupby()`, `.mean()`, `plt.subplots()`, `ax.set_xlabel()`, `ax.set_ylabel()`, `ax.legend()`, `plt.savefig()`

# %%
# plan:

# %%
# plan:

# %%
# plan:

# %% [markdown]
# *What do these show? What did you expect, and what surprised you?*

# %% [markdown]
# ---
# # Step 11 — Prove you could get it again
#
# *A download needs a human. An API does not — so it can be repeated, scheduled, and checked. The acquisition slide asked: can I get this again next year, the same way, and prove it? This is where you answer.*
#
# - **If your dataset has an API:** re-request the data you analysed in Step 10, with code instead of clicking. **Show one number matching** between your downloaded file and the API pull — that match is the proof.
# - **If it does not:** use the National Weather Service active alerts feed instead — <https://api.weather.gov/alerts/active>, no key, no account. Then add one line: what would you have to do to turn that response into a dataframe like the one you already have?
#
# Either way, show that you can:
#
# - make the request and confirm it worked
# - turn the response into something Python can navigate
# - reach one specific value, several levels down
#
# *Worth looking at:* `requests.get()`, `.status_code`, `.json()`, `.keys()`, list indexing, `pd.json_normalize()`

# %%
# plan:

# %%
# plan:

# %% [markdown]
# *The number that matched — or, if you used weather.gov, what it would take to get that response into your dataframe.*

# %% [markdown]
# ---
# # Step 12 — Share and use
#
# *Markdown only. No code. This is the closing of the lifecycle.*
#
# - What can you say from this data, with confidence?
# - What can you **not** say? Start from the thing you named in class that this dataset would not let you answer.
# - What assumptions did you make while cleaning that a reader should know about?
# - Who would use this, and what would they need next?

# %% [markdown]
# *Your answer here.*

# %% [markdown]
# ---
# # Exercises (optional)
#
# *Not graded. Here because they are worth an hour some evening.*
#
# ### 1. Two y-axes
#
# Put two sources on one plot — corn prices and agricultural land values, same state — using `ax.twinx()`. What moves first? Genuinely fiddly, which is why it is here rather than in Step 10.
#
# ### 2. Install a package you need
#
# Python's real strength is the ecosystem. `yfinance` gives you commodity and stock prices:
#
# ```
# pip install yfinance
# ```
#
# - Corn futures are ticker `ZC=F`; the full commodity list is at <https://finance.yahoo.com/commodities/>.
# - `yf.Ticker("ZC=F").history(start="2000-01-01")` returns a dataframe — the same shape as `read_csv` gives you.
# - Plot it against something from your own dataset. Does the pairing tell a story?
#
# ### 3. Clean a dirty file yourself
#
# `aglandvalues-clean.csv` in this folder was cleaned for you. The raw version had `(NA)`, `(D)` and `(S)` in the Value column, and numbers written with commas (`"3,500"`) that would not convert to float. Download the raw data from <https://quickstats.nass.usda.gov/> and clean it yourself.

# %% [markdown]
# ---
# ## Before you submit
#
# - [ ] Raw data file committed
# - [ ] Cleaned data file committed, under a different name
# - [ ] Every plot saved as a file and committed
# - [ ] Every code cell has its plan written above it as comments
# - [ ] Every step has a markdown cell explaining what you found
# - [ ] Notebook runs top to bottom without errors — restart the kernel and run all
# - [ ] 4+ commits, each with a message that says what changed and why
# - [ ] Submitted on GitHub **and** Brightspace
