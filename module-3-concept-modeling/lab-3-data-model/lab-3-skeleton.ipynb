# %% [markdown]
# # ASM 532 — Lab 3: Data Model
#
# **Name:**
# **Domain:**
# **Date:**

# %% [markdown]
# ## How to use this template
#
# This notebook is a worksheet, not a tutorial. It works for **your** data model, whatever
# domain you chose — there is no answer key, because nobody else modelled your system.
#
# Each section gives you a question and a `# plan:` cell. **Write the plan first, in plain
# English, as comments.** Then write the code under it. That order is deliberate: it is how
# you find out whether you understand the problem before the syntax gets in the way, and it
# is what this lab's AI policy asks of you.
#
# Before you start you should have, from Part 2:
#
# - your data model diagram (STEP 5)
# - two of your own tables in a database file, with one foreign key (STEP 7)
# - `data_model.py` open beside this notebook
#
# Delete the `# plan:` prompts as you replace them. Keep your prose answers — they are graded.

# %% [markdown]
# ---
# ## Setup
#
# Point this at **your** database file from STEP 7, not the crop tracker.

# %%
import sqlite3
from sqlalchemy import create_engine, select
from sqlalchemy.orm import Session

# YOUR CODE HERE: the name of your own database file, from STEP 7
DB_FILE = "yourdomain.db"   # YOUR CODE HERE

engine = create_engine(f"sqlite:///{DB_FILE}")
print("connected to", DB_FILE)

# %% [markdown]
# ---
# ## 1. Check what SQL already built
#
# Before bringing SQLAlchemy in, confirm from Python that the tables you made in STEP 7 are
# really there. This is the plain `sqlite3` library — the same SQL you typed at the prompt,
# sent from a program instead.

# %%
# plan:
# - open a connection with sqlite3
# - ask for the list of tables
# - print the rows of one of your tables

# %% [markdown]
# *Which tables came back, and did anything surprise you?*
#
# **Your answer here.**

# %% [markdown]
# ---
# ## 2. Describe your objects as Python classes
#
# Open `data_model.py`. Read the worked `Crop` and `Plot` example, then complete the two stubs
# so they match the tables you built.
#
# Then import them here. If the import fails, the error is telling you something real about
# your model — read it before changing anything.

# %%
# plan:
# - import your two classes from data_model
# - print each class's __tablename__ to confirm they match your database

# %% [markdown]
# *What did you have to decide while writing the classes that your diagram had left open?*
#
# **Your answer here.**

# %% [markdown]
# ---
# ## 3. Add a row from Python
#
# A row is now an object. Create one, add it to a session, and commit.

# %%
# plan:
# - open a Session on the engine
# - build one instance of your first object
# - add it, commit it, and print it back

# %% [markdown]
# Now try to break it on purpose: add a row that violates one of your constraints — a missing
# `not null` value, or a foreign key pointing at something that does not exist.
#
# *What was the error, and which constraint caught it?*
#
# **Your answer here.**

# %% [markdown]
# ---
# ## 4. Query one object
#
# Answer a real question about your domain that needs **one** of your objects: a filter, a sort,
# or both.
#
# **The question you are answering:** *YOUR ANSWER HERE — write it before you write any code.*

# %%
# plan:
# - which object, and which attribute are you filtering or sorting on?
# - what result would tell you the answer?

# %% [markdown]
# *What did the result tell you?*
#
# **Your answer here.**

# %% [markdown]
# ---
# ## 5. Query across the relationship
#
# Now a question that needs **both** objects — one that can only be answered by following the
# foreign key. This is what the relationship was for.
#
# **The question you are answering:** *YOUR ANSWER HERE — write it first.*

# %%
# plan:
# - start from which object?
# - follow the relationship in which direction?
# - what are you filtering, counting, or sorting once you are across?

# %% [markdown]
# *Was following the relationship from Python easier or harder than writing the same thing in
# SQL? Why?*
#
# **Your answer here.**

# %% [markdown]
# ---
# ## 6. Reflect
#
# You have now expressed the same model three times: as a paper sketch, as a diagram, and as
# tables and classes.
#
# **What did the database force you to decide that the paper sketch let you leave vague?**
#
# **Your answer here.**
#
# *Optional, but worth it: what would you change about your STEP 5 diagram now? Update it —*
# *a data model that no longer matches its database is worse than no diagram at all.*

# %% [markdown]
# ---
# Remember to commit your work, and to push your database file, your `data_model.py`, and this
# notebook to your `lab3` folder.
